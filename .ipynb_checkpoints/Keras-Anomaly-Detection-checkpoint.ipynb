# %% [markdown]
# # Time Series Anomaly Detection Using Keras

# %% [markdown]
# ## Install and Import Dependencies

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 1.5 MB/s eta 0:00:01
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in /Users/maxmohammadi/opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=6c018a86f416a38fa84c68e0f681455a26d7d39d9f40a39590abc5fc507b22ed
#   Stored in directory: /Users/maxmohammadi/Library/Caches/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.14.3 retrying-1.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
pd.options.mode.chained_assignment = None
import seaborn as sns
from matplotlib.pylab import rcParams
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %matplotlib inline

sns.set(style="whitegrid", palette="muted")
rcParams["figure.figsize"] = 14, 8
np.random.seed(1)
tf.random.set_seed(1)

# %% [markdown]
# ## Load and Inspect ArcSim Telemetry

# %%
df = pd.read_csv("S&P_500_Index_Data.csv", parse_dates=["date"])
df.head()
# Out:
#         date   close
# 0 1986-01-02  209.59
# 1 1986-01-03  210.88
# 2 1986-01-06  210.65
# 3 1986-01-07  213.80
# 4 1986-01-08  207.97

# %%
df.shape
# Out:
# (8192, 2)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["date"], y=df["close"], mode="lines", name="Data Rate (example)"))
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <div>                            <div id="3a5a2528-752e-45e2-8336-9ab5267c6ea5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a5a2528-752e-45e2-8336-9ab5267c6ea5")) {                    Plotly.newPlot(                        "3a5a2528-752e-45e2-8336-9ab5267c6ea5",                        [{"mode": "lines", "name": "Data Rate (example)", "type": "scatter", "x": ["1986-01-02T00:00:00", "1986-01-03T00:00:00", "1986-01-06T00:00:00", "1986-01-07T00:00:00", "1986-01-08T00:00:00", "1986-01-09T00:00:00", "1986-01-10T00:00:00", "1986-01-13T00:00:00", "1986-01-14T00:00:00", "1986-01-15T00:00:00", "1986-01-16T00:00:00", "1986-01-17T00:00:00", "1986-01-20T00:00:00", "1986-01-21T00:00:00", "1986-01-22T00:00:00", "1986-01-23T00:00:00", "1986-01-24T00:00:00", "1986-01-27T00:00:00", "1986-01-28T00:00:00", "1986-01-29T00:00:00", "1986-01-30T00:00:00", "1986-01-31T00:00:00", "1986-02-03T00:00:00", "1986-02-04T00:00:00", "1986-02-05T00:00:00", "1986-02-06T00:00:00", "1986-02-07T00:00:00", "1986-02-10T00:00:00", "1986-02-11T00:00:00", "1986-02-12T00:00:00", "1986-02-13T00:00:00", "1986-02-14T00:00:00", "1986-02-18T00:00:00", "1986-02-19T00:00:00", "1986-02-20T00:00:00", "1986-02-21T00:00:00", "1986-02-24T00:00:00", "1986-02-25T00:00:00", "1986-02-26T00:00:00", "1986-02-27T00:00:00", "1986-02-28T00:00:00", "1986-03-03T00:00:00", "1986-03-04T00:00:00", "1986-03-05T00:00:00", "1986-03-06T00:00:00", "1986-03-07T00:00:00", "1986-03-10T00:00:00", "1986-03-11T00:00:00", "1986-03-12T00:00:00", "1986-03-13T00:00:00", "1986-03-14T00:00:00", "1986-03-17T00:00:00", "1986-03-18T00:00:00", "1986-03-19T00:00:00", "1986-03-20T00:00:00", "1986-03-21T00:00:00", "1986-03-24T00:00:00", "1986-03-25T00:00:00", "1986-03-26T00:00:00", "1986-03-27T00:00:00", "1986-03-31T00:00:00", "1986-04-01T00:00:00", "1986-04-02T00:00:00", "1986-04-03T00:00:00", "1986-04-04T00:00:00", "1986-04-07T00:00:00", "1986-04-08T00:00:00", "1986-04-09T00:00:00", "1986-04-10T00:00:00", "1986-04-11T00:00:00", "1986-04-14T00:00:00", "1986-04-15T00:00:00", "1986-04-16T00:00:00", "1986-04-17T00:00:00", "1986-04-18T00:00:00", "1986-04-21T00:00:00", "1986-04-22T00:00:00", "1986-04-23T00:00:00", "1986-04-24T00:00:00", "1986-04-25T00:00:00", "1986-04-28T00:00:00", "1986-04-29T00:00:00", "1986-04-30T00:00:00", "1986-05-01T00:00:00", "1986-05-02T00:00:00", "1986-05-05T00:00:00", "1986-05-06T00:00:00", "1986-05-07T00:00:00", "1986-05-08T00:00:00", "1986-05-09T00:00:00", "1986-05-12T00:00:00", "1986-05-13T00:00:00", "1986-05-14T00:00:00", "1986-05-15T00:00:00", "1986-05-16T00:00:00", "1986-05-19T00:00:00", "1986-05-20T00:00:00", "1986-05-21T00:00:00", "1986-05-22T00:00:00", "1986-05-23T00:00:00", "1986-05-27T00:00:00", "1986-05-28T00:00:00", "1986-05-29T00:00:00", "1986-05-30T00:00:00", "1986-06-02T00:00:00", "1986-06-03T00:00:00", "1986-06-04T00:00:00", "1986-06-05T00:00:00", "1986-06-06T00:00:00", "1986-06-09T00:00:00", "1986-06-10T00:00:00", "1986-06-11T00:00:00", "1986-06-12T00:00:00", "1986-06-13T00:00:00", "1986-06-16T00:00:00", "1986-06-17T00:00:00", "1986-06-18T00:00:00", "1986-06-19T00:00:00", "1986-06-20T00:00:00", "1986-06-23T00:00:00", "1986-06-24T00:00:00", "1986-06-25T00:00:00", "1986-06-26T00:00:00", "1986-06-27T00:00:00", "1986-06-30T00:00:00", "1986-07-01T00:00:00", "1986-07-02T00:00:00", "1986-07-03T00:00:00", "1986-07-07T00:00:00", "1986-07-08T00:00:00", "1986-07-09T00:00:00", "1986-07-10T00:00:00", "1986-07-11T00:00:00", "1986-07-14T00:00:00", "1986-07-15T00:00:00", "1986-07-16T00:00:00", "1986-07-17T00:00:00", "1986-07-18T00:00:00", "1986-07-21T00:00:00", "1986-07-22T00:00:00", "1986-07-23T00:00:00", "1986-07-24T00:00:00", "1986-07-25T00:00:00", "1986-07-28T00:00:00", "1986-07-29T00:00:00", "1986-07-30T00:00:00", "1986-07-31T00:00:00", "1986-08-01T00 ...

# %% [markdown]
# ## Data Preprocessing

# %%
# 80% of the data for training (past events)
# 20% used for testing (new events)
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size

train = df.iloc[0:train_size]
test = df.iloc[train_size:len(df)]

print(train.shape, test.shape)
# Out:
# (6553, 2) (1639, 2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler = scaler.fit(train[["close"]])

train["close"] = scaler.transform(train[["close"]])
test["close"] = scaler.transform(test[["close"]])

# %% [markdown]
# ## Create Training and Test Splits

# %%
def create_sequences(x, y, time_steps=1):
    x_list, y_list = [], []
    
    for i in range(len(x) - time_steps):
        x_list.append(x.iloc[i:(i+time_steps)].values)
        y_list.append(y.iloc[i+time_steps])
    
    return np.array(x_list), np.array(y_list)

# %%
time_steps = 30 #hours

x_train, y_train = create_sequences(train[["close"]], train["close"], time_steps)
x_test, y_test = create_sequences(test[["close"]], test["close"], time_steps)

# %%
x_train.shape
# Out:
# (6523, 30, 1)

# %% [markdown]
# ## Build an LSTM Autoencoder

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers  import Dense, LSTM, Dropout, RepeatVector, TimeDistributed

# %%
# Train the autoencoder on normal data that does not contain any anomalies

timesteps = x_train.shape[1]
num_features = x_train.shape[2]

# %%
# model = Sequential()
# model.add(LSTM(
#     units=64,
#     input_shape=(x_train.shape[1], x_train.shape[2])
# ))
# model.add(Dropout(rate=0.2))
# model.add(RepeatVector(n=x_train.shape[1]))
# model.add(LSTM(units=64, return_sequences=True))
# model.add(Dropout(rate=0.2))
# model.add(TimeDistributed(Dense(units=x_train.shape[2])))
# model.compile(loss='mae', optimizer='adam')

# %%
model = Sequential([
    LSTM(128, input_shape=(timesteps, num_features)),
    Dropout(0.2),
    RepeatVector(timesteps),
    LSTM(128, return_sequences=True),
    Dropout(0.2),
    TimeDistributed(Dense(num_features))
])

model.compile(loss="mae", optimizer="adam")
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_25 (LSTM)               (None, 128)               66560
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# repeat_vector_12 (RepeatVect (None, 30, 128)           0
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 30, 128)           131584
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 30, 128)           0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 30, 1)             129
# =================================================================
# Total params: 198,273
# Trainable params: 198,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the LSTM Autoencoder

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, mode="min")
history = model.fit(
    x_train, 
    y_train, 
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1428 - val_loss: 0.1469
# Epoch 2/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.1104 - val_loss: 0.1322
# Epoch 3/100
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1003 - val_loss: 0.0491
# Epoch 4/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0816 - val_loss: 0.0531
# Epoch 5/100
# 184/184 [==============================] - 6s 30ms/step - loss: 0.0775 - val_loss: 0.0552
# Epoch 6/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0780 - val_loss: 0.0335
# Epoch 7/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0740 - val_loss: 0.1169
# Epoch 8/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0803 - val_loss: 0.0383
# Epoch 9/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0720 - val_loss: 0.0283
# Epoch 10/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0733 - val_loss: 0.0281
# Epoch 11/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0718 - val_loss: 0.0449
# Epoch 12/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0767 - val_loss: 0.0652
# Epoch 13/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0777 - val_loss: 0.0301
# Epoch 14/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0726 - val_loss: 0.0317
# Epoch 15/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0731 - val_loss: 0.0416
# Epoch 16/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0723 - val_loss: 0.0284
# Epoch 17/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0718 - val_loss: 0.0784
# Epoch 18/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0769 - val_loss: 0.0326
# Epoch 19/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0713 - val_loss: 0.0553
# Epoch 20/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0726 - val_loss: 0.0357
# Epoch 21/100
# 184/184 [==============================] - 6s 30ms/step - loss: 0.0713 - val_loss: 0.0473
# Epoch 22/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0740 - val_loss: 0.0580
# Epoch 23/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0753 - val_loss: 0.0700
# Epoch 24/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0787 - val_loss: 0.0837
# Epoch 25/100
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0841 - val_loss: 0.1012
# Epoch 26/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0922 - val_loss: 0.1182
# Epoch 27/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0977 - val_loss: 0.1285
# Epoch 28/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1206 - val_loss: 0.1283
# Epoch 29/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1301 - val_loss: 0.1317
# Epoch 30/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1160 - val_loss: 0.1449
# Epoch 31/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1040 - val_loss: 0.1210
# Epoch 32/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0986 - val_loss: 0.1324
# Epoch 33/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0929 - val_loss: 0.1160
# Epoch 34/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0915 - val_loss: 0.1152
# Epoch 35/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0892 - val_loss: 0.1169
# Epoch 36/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0855 - val_loss: 0.1171
# Epoch 37/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0850 - val_loss: 0.1068
# Epoch 38/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0829 - val_loss: 0.1053
# Epoch 39/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0846 - val_loss: 0.1118
# Epoch 40/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0812 - val_loss: 0.0953
# Epoch 41/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0841 - val_loss: 0.0922
# Epoch 42/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0822 - val_loss: 0.0955
# Epoch 43/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0814 - val_loss: 0.0863
# Epoch 44/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0823 - val_loss: 0.0943
# Epoch 45/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0815 - val_loss: 0.0933
# Epoch 46/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0794 - val_loss: 0.0860
# Epoch 47/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0810 - val_loss: 0.0910
# Epoch 48/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0785 - val_loss: 0.0896
# Epoch 49/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0776 - val_loss: 0.0841
# Epoch 50/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0786 - val_loss: 0.0873
# Epoch 51/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0779 - val_loss: 0.0866
# Epoch 52/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0784 - val_loss: 0.0883
# Epoch 53/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0769 - val_loss: 0.0849
# Epoch 54/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0773 - val_loss: 0.0878
# Epoch 55/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0763 - val_loss: 0.0813
# Epoch 56/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0759 - val_loss: 0.0801
# Epoch 57/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0766 - val_loss: 0.0849
# Epoch 58/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0762 - val_loss: 0.0764
# Epoch 59/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0756 - val_loss: 0.0754
# Epoch 60/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0751 - val_loss: 0.0753
# Epoch 61/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0756 - val_loss: 0.0747
# Epoch 62/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0775 - val_loss: 0.0766
# Epoch 63/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0755 - val_loss: 0.0778
# Epoch 64/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0741 - val_loss: 0.0881
# Epoch 65/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0745 - val_loss: 0.0754
# Epoch 66/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0745 - val_loss: 0.0817
# Epoch 67/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0738 - val_loss: 0.0701
# Epoch 68/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0737 - val_loss: 0.0757
# Epoch 69/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0725 - val_loss: 0.0717
# Epoch 70/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0732 - val_loss: 0.0713
# Epoch 71/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0727 - val_loss: 0.0732
# Epoch 72/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0722 - val_loss: 0.0762
# Epoch 73/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0721 - val_loss: 0.0683
# Epoch 74/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0732 - val_loss: 0.0687
# Epoch 75/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0724 - val_loss: 0.0706
# Epoch 76/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0727 - val_loss: 0.0682
# Epoch 77/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0723 - val_loss: 0.0717
# Epoch 78/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0718 - val_loss: 0.0752
# Epoch 79/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0701 - val_loss: 0.0633
# Epoch 80/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0705 - val_loss: 0.0670
# Epoch 81/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0709 - val_loss: 0.0693
# Epoch 82/100
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0712 - val_loss: 0.0673
# Epoch 83/100
# 184/184 [==============================] - 7s 35ms/step - loss: 0.0707 - val_loss: 0.0639
# Epoch 84/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.0714 - val_loss: 0.0656
# Epoch 85/100
# 184/184 [==============================] - 7s 35ms/step - loss: 0.0710 - val_loss: 0.0677
# Epoch 86/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0706 - val_loss: 0.0640
# Epoch 87/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0699 - val_loss: 0.0623
# Epoch 88/100
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0705 - val_loss: 0.0642
# Epoch 89/100
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0718 - val_loss: 0.0628
# Epoch 90/100
# 184/184 [==============================] - 7s 35ms/step - loss: 0.0712 - val_loss: 0.0649
# Epoch 91/100
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0696 - val_loss: 0.0629
# Epoch 92/100
# 184/184 [==============================] - 7s 38ms/step - loss: 0.0703 - val_loss: 0.0669
# Epoch 93/100
# 184/184 [==============================] - 7s 35ms/step - loss: 0.0693 - val_loss: 0.0681
# Epoch 94/100
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0686 - val_loss: 0.0659
# Epoch 95/100
# 184/184 [==============================] - 7s 39ms/step - loss: 0.0686 - val_loss: 0.0645
# Epoch 96/100
# 184/184 [==============================] - 7s 39ms/step - loss: 0.0684 - val_loss: 0.0686
# Epoch 97/100
# 184/184 [==============================] - 7s 39ms/step - loss: 0.0689 - val_loss: 0.0650
# Epoch 98/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.0687 - val_loss: 0.0673
# Epoch 99/100
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0690 - val_loss: 0.0654
# Epoch 100/100
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0689 - val_loss: 0.0611

# %% [markdown]
# ## Plot Metrics and Evaluate the Model

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend();

# %%
# Calculate Mean Absolute Error
x_train_pred = model.predict(x_train)

train_mae_loss = pd.DataFrame(np.mean(np.abs(x_train_pred - x_train), axis=1), columns=["Error"])

# %%
model.evaluate(x_test, y_test)
# Out:
# 51/51 [==============================] - 1s 10ms/step - loss: 1.2107
# 1.2107328176498413

# %%
sns.displot(train_mae_loss, bins=50, kde=True)

# %%
threshold = 1.4

# %%
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred, x_test), axis=1)

# %% [markdown]
# ## Detect Anomalies in the Spacecraft Telemetry

# %%
test_score_df = pd.DataFrame(index=test[time_steps:].index)
test_score_df["loss"] = test_mae_loss
test_score_df["threshold"] = threshold
test_score_df["anomaly"] = test_score_df.loss > test_score_df.threshold
test_score_df["close"] = test[time_steps:].close

# %%
test_score_df.head()
# Out:
#           loss  threshold  anomaly    close
# 6583  1.127479        1.4    False  1349.96
# 6584  1.128807        1.4    False  1351.95
# 6585  1.129644        1.4    False  1342.64
# 6586  1.121389        1.4    False  1351.77
# 6587  1.128867        1.4    False  1350.50

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=test[time_steps:]["date"], 
    y=test_score_df.loss,
    mode="lines",
    name="Test Loss"
))

fig.add_trace(go.Scatter(
    x=test[time_steps:]["date"], 
    y=test_score_df.threshold,
    mode="lines",
    name="Threshold"
))

fig.update_layout(showlegend=True)
fig.show()
# Out:
# <div>                            <div id="73ac0cfc-d0b0-4fc1-94b5-f6f27b8c78f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73ac0cfc-d0b0-4fc1-94b5-f6f27b8c78f3")) {                    Plotly.newPlot(                        "73ac0cfc-d0b0-4fc1-94b5-f6f27b8c78f3",                        [{"mode": "lines", "name": "Test Loss", "type": "scatter", "x": ["2012-02-08T00:00:00", "2012-02-09T00:00:00", "2012-02-10T00:00:00", "2012-02-13T00:00:00", "2012-02-14T00:00:00", "2012-02-15T00:00:00", "2012-02-16T00:00:00", "2012-02-17T00:00:00", "2012-02-21T00:00:00", "2012-02-22T00:00:00", "2012-02-23T00:00:00", "2012-02-24T00:00:00", "2012-02-27T00:00:00", "2012-02-28T00:00:00", "2012-02-29T00:00:00", "2012-03-01T00:00:00", "2012-03-02T00:00:00", "2012-03-05T00:00:00", "2012-03-06T00:00:00", "2012-03-07T00:00:00", "2012-03-08T00:00:00", "2012-03-09T00:00:00", "2012-03-12T00:00:00", "2012-03-13T00:00:00", "2012-03-14T00:00:00", "2012-03-15T00:00:00", "2012-03-16T00:00:00", "2012-03-19T00:00:00", "2012-03-20T00:00:00", "2012-03-21T00:00:00", "2012-03-22T00:00:00", "2012-03-23T00:00:00", "2012-03-26T00:00:00", "2012-03-27T00:00:00", "2012-03-28T00:00:00", "2012-03-29T00:00:00", "2012-03-30T00:00:00", "2012-04-02T00:00:00", "2012-04-03T00:00:00", "2012-04-04T00:00:00", "2012-04-05T00:00:00", "2012-04-09T00:00:00", "2012-04-10T00:00:00", "2012-04-11T00:00:00", "2012-04-12T00:00:00", "2012-04-13T00:00:00", "2012-04-16T00:00:00", "2012-04-17T00:00:00", "2012-04-18T00:00:00", "2012-04-19T00:00:00", "2012-04-20T00:00:00", "2012-04-23T00:00:00", "2012-04-24T00:00:00", "2012-04-25T00:00:00", "2012-04-26T00:00:00", "2012-04-27T00:00:00", "2012-04-30T00:00:00", "2012-05-01T00:00:00", "2012-05-02T00:00:00", "2012-05-03T00:00:00", "2012-05-04T00:00:00", "2012-05-07T00:00:00", "2012-05-08T00:00:00", "2012-05-09T00:00:00", "2012-05-10T00:00:00", "2012-05-11T00:00:00", "2012-05-14T00:00:00", "2012-05-15T00:00:00", "2012-05-16T00:00:00", "2012-05-17T00:00:00", "2012-05-18T00:00:00", "2012-05-21T00:00:00", "2012-05-22T00:00:00", "2012-05-23T00:00:00", "2012-05-24T00:00:00", "2012-05-25T00:00:00", "2012-05-29T00:00:00", "2012-05-30T00:00:00", "2012-05-31T00:00:00", "2012-06-01T00:00:00", "2012-06-04T00:00:00", "2012-06-05T00:00:00", "2012-06-06T00:00:00", "2012-06-07T00:00:00", "2012-06-08T00:00:00", "2012-06-11T00:00:00", "2012-06-12T00:00:00", "2012-06-13T00:00:00", "2012-06-14T00:00:00", "2012-06-15T00:00:00", "2012-06-18T00:00:00", "2012-06-19T00:00:00", "2012-06-20T00:00:00", "2012-06-21T00:00:00", "2012-06-22T00:00:00", "2012-06-25T00:00:00", "2012-06-26T00:00:00", "2012-06-27T00:00:00", "2012-06-28T00:00:00", "2012-06-29T00:00:00", "2012-07-02T00:00:00", "2012-07-03T00:00:00", "2012-07-05T00:00:00", "2012-07-06T00:00:00", "2012-07-09T00:00:00", "2012-07-10T00:00:00", "2012-07-11T00:00:00", "2012-07-12T00:00:00", "2012-07-13T00:00:00", "2012-07-16T00:00:00", "2012-07-17T00:00:00", "2012-07-18T00:00:00", "2012-07-19T00:00:00", "2012-07-20T00:00:00", "2012-07-23T00:00:00", "2012-07-24T00:00:00", "2012-07-25T00:00:00", "2012-07-26T00:00:00", "2012-07-27T00:00:00", "2012-07-30T00:00:00", "2012-07-31T00:00:00", "2012-08-01T00:00:00", "2012-08-02T00:00:00", "2012-08-03T00:00:00", "2012-08-06T00:00:00", "2012-08-07T00:00:00", "2012-08-08T00:00:00", "2012-08-09T00:00:00", "2012-08-10T00:00:00", "2012-08-13T00:00:00", "2012-08-14T00:00:00", "2012-08-15T00:00:00", "2012-08-16T00:00:00", "2012-08-17T00:00:00", "2012-08-20T00:00:00", "2012-08-21T00:00:00", "2012-08-22T00:00:00", "2012-08-23T00:00:00", "2012-08-24T00:00:00", "2012-08-27T00:00:00", "2012-08-28T00:00:00", "2012-08-29T00:00:00", "2012-08-30T00:00:00", "2012-08-31T00:00:00", "2012-09-04T00:00:00", "2012-09-05T00:00:00", "2012-09-06T00:00:00", "2012-09-07T00:00:00", " ...

# %%
anomalies = test_score_df[test_score_df.anomaly == True]
anomalies.head()
# Out:
#           loss  threshold  anomaly    close
# 7177  1.400147        1.4     True  1962.87
# 7178  1.401063        1.4     True  1962.61
# 7179  1.401054        1.4     True  1949.98
# 7181  1.400255        1.4     True  1957.22
# 7183  1.400428        1.4     True  1960.23

# %%
plt.plot(
    test[time_steps:].index,
    scaler.inverse_transform(test[time_steps:].close),
    label="close price"
);

sns.scatterplot(
    anomalies.index,
    scaler.inverse_transform(anomalies.close),
    color=sns.color_palette()[3],
    s=52,
    label="anomaly"
)
plt.xticks(rotation=25)
plt.legend()
# Out:
# /Users/maxmohammadi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
